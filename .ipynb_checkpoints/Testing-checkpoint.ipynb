# %%
import numpy as np
import tensorflow as tf

# import sys
# sys.path.append('src/suction_based_grasping/baseline')
# sys.path.append('src')

from src.suction_based_grasping.baseline.test import *

# %%
input_color, input_depth, background_color, background_depth = test()
print(input_color)

im = input_color
plt.figure()
plt.imshow(im)
plt.axis('off')
# Out:
# [[[0.35686275 0.9607843  0.61960787]
#   [0.5019608  1.         0.7647059 ]
#   [0.         0.3254902  0.21568628]
#   ...
#   [0.         0.39215687 0.23529412]
#   [0.01176471 0.39215687 0.23137255]
#   [0.00784314 0.3882353  0.22745098]]
#
#  [[0.         0.31764707 0.16078432]
#   [0.         0.32156864 0.16470589]
#   [0.         0.32941177 0.19607843]
#   ...
#   [0.         0.39607844 0.22352941]
#   [0.00784314 0.39607844 0.23137255]
#   [0.00392157 0.39215687 0.22745098]]
#
#  [[0.         0.3254902  0.14509805]
#   [0.         0.32941177 0.14901961]
#   [0.         0.32941177 0.16862746]
#   ...
#   [0.         0.39607844 0.21568628]
#   [0.         0.40392157 0.22352941]
#   [0.         0.4        0.21960784]]
#
#  ...
#
#  [[0.7529412  0.4627451  0.40392157]
#   [0.75686276 0.46666667 0.40784314]
#   [0.7607843  0.45490196 0.38431373]
#   ...
#   [0.54509807 0.11764706 0.07843138]
#   [0.5372549  0.11764706 0.07843138]
#   [0.5372549  0.11764706 0.07843138]]
#
#  [[0.7529412  0.47843137 0.40392157]
#   [0.7372549  0.4627451  0.3882353 ]
#   [0.7294118  0.3882353  0.32941177]
#   ...
#   [0.5803922  0.14901961 0.09411765]
#   [0.5686275  0.14509805 0.09411765]
#   [0.56078434 0.13725491 0.08627451]]
#
#  [[0.7607843  0.4745098  0.40392157]
#   [0.7058824  0.41960785 0.34901962]
#   [0.6862745  0.32156864 0.27058825]
#   ...
#   [0.65882355 0.23137255 0.15686275]
#   [0.654902   0.23137255 0.17254902]
#   [0.65882355 0.23529412 0.1764706 ]]]
