# %%
import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt
import os

# %matplotlib inline
# %load_ext autoreload
# %autoreload 2

from src.suction_based_grasping.utils import *
from src.suction_based_grasping.convnet.model import *
from src.suction_based_grasping.convnet.data_utils import *

from keras import models # for load_model
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
# X_target_shape = (960, 1280) # height and width of inputs to ResNet50
X_target_shape = (480, 640) # height and width of inputs to ResNet50
y_target_shape = (480, 640)
model_filepath = '/home/shared/project/src/suction_based_grasping/convnet/models'

# %%
# load test/train data
X_train, X_test, y_train, y_test = train_test_split("train-split.txt", "test-split.txt", num_train=1s, num_test=20, X_target_shape=X_target_shape, y_target_shape=y_target_shape)
# Out:
# Loading Training Data from train-split.txt
# 2/100	2.00%
# /usr/local/lib/python3.5/dist-packages/skimage/transform/_warps.py:105: UserWarning: The default mode, 'constant', will be changed to 'reflect' in skimage 0.15.
#   warn("The default mode, 'constant', will be changed to 'reflect' in "
# /usr/local/lib/python3.5/dist-packages/skimage/transform/_warps.py:110: UserWarning: Anti-aliasing will be enabled by default in skimage 0.15 to avoid aliasing artifacts when down-sampling images.
#   warn("Anti-aliasing will be enabled by default in skimage 0.15 to "
# Done!00	100.00%
# Loading Test Data from test-split.txt
# Done!	100.00%

# %%
plt.imshow(X_train[0][0])
plt.figure()
plt.imshow(y_train[0])
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
model = init_model(X_target_shape, y_target_shape)

# %%
train_batch_size = 100
val_batch_size = 20

img_names = read_split_file("train-split.txt")
N = len(img_names)
validation_split = 0.2
N_train = int((1-validation_split)*N)
N_val = N-N_train
train_img_names = img_names[0:N_train]
val_img_names = img_names[N_train:N]

model.fit_generator(
    image_generator(train_img_names, train_batch_size, X_target_shape=X_target_shape, y_target_shape=y_target_shape),
    validation_data=image_generator(val_img_names, val_batch_size, X_target_shape=X_target_shape, y_target_shape=y_target_shape),
    validation_steps=1,
    steps_per_epoch=2, epochs=1, verbose=2)
# Out:
# Epoch 1/10
# /usr/local/lib/python3.5/dist-packages/skimage/transform/_warps.py:105: UserWarning: The default mode, 'constant', will be changed to 'reflect' in skimage 0.15.
#   warn("The default mode, 'constant', will be changed to 'reflect' in "
# /usr/local/lib/python3.5/dist-packages/skimage/transform/_warps.py:110: UserWarning: Anti-aliasing will be enabled by default in skimage 0.15 to avoid aliasing artifacts when down-sampling images.
#   warn("Anti-aliasing will be enabled by default in skimage 0.15 to "
# 20/20	100.00%

# %%
# save model
model_name = 'model_f'
model.save(os.path.join(model_filepath, model_name))

# %%
# load model
model_name = 'model_b'
model = models.load_model(os.path.join(model_filepath, model_name), custom_objects={'heatmap_loss': heatmap_loss})

# %%
# fit model to real data
model.fit(x=X_train, y=y_train, epochs=1, batch_size=2, validation_split=0.2, verbose=2)
# Out:
# Train on 80 samples, validate on 20 samples
# Epoch 1/1
#  - 258s - loss: 0.8785 - acc: 0.8371 - val_loss: 0.6501 - val_acc: 0.8337

# %%
# test prediction
img_idx = 99
color = X_train[0][np.newaxis, img_idx]
depth = X_train[1][np.newaxis, img_idx]
heatmap = model.predict([color, depth])[0]

plt.figure(figsize=(20, 50))
plt.subplot(1, 4, 1)
plt.axis('off')
plt.imshow(X_train[0][img_idx])
plt.subplot(1, 4, 2)
plt.axis('off')
plt.imshow(X_train[1][img_idx])
plt.subplot(1, 4, 3)
plt.axis('off')
plt.imshow(heatmap) # remove minibatch dim
plt.subplot(1, 4, 4)
plt.axis('off')
plt.imshow(y_train[img_idx])
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
model.summary()
# Out:
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1_color (InputLayer)      (None, 960, 1280, 3) 0
# __________________________________________________________________________________________________
# input_2_depth (InputLayer)      (None, 960, 1280, 3) 0
# __________________________________________________________________________________________________
# conv1_pad_color (ZeroPadding2D) (None, 966, 1286, 3) 0           input_1_color[0][0]
# __________________________________________________________________________________________________
# conv1_pad_depth (ZeroPadding2D) (None, 966, 1286, 3) 0           input_2_depth[0][0]
# __________________________________________________________________________________________________
# conv1_color (Conv2D)            (None, 480, 640, 64) 9472        conv1_pad_color[0][0]
# __________________________________________________________________________________________________
# conv1_depth (Conv2D)            (None, 480, 640, 64) 9472        conv1_pad_depth[0][0]
# __________________________________________________________________________________________________
# bn_conv1_color (BatchNormalizat (None, 480, 640, 64) 256         conv1_color[0][0]
# __________________________________________________________________________________________________
# bn_conv1_depth (BatchNormalizat (None, 480, 640, 64) 256         conv1_depth[0][0]
# __________________________________________________________________________________________________
# activation_1_color (Activation) (None, 480, 640, 64) 0           bn_conv1_color[0][0]
# __________________________________________________________________________________________________
# activation_50_depth (Activation (None, 480, 640, 64) 0           bn_conv1_depth[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_1_color (MaxPooli (None, 239, 319, 64) 0           activation_1_color[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_2_depth (MaxPooli (None, 239, 319, 64) 0           activation_50_depth[0][0]
# __________________________________________________________________________________________________
# res2a_branch2a_color (Conv2D)   (None, 239, 319, 64) 4160        max_pooling2d_1_color[0][0]
# __________________________________________________________________________________________________
# res2a_branch2a_depth (Conv2D)   (None, 239, 319, 64) 4160        max_pooling2d_2_depth[0][0]
# __________________________________________________________________________________________________
# bn2a_branch2a_color (BatchNorma (None, 239, 319, 64) 256         res2a_branch2a_color[0][0]
# __________________________________________________________________________________________________
# bn2a_branch2a_depth (BatchNorma (None, 239, 319, 64) 256         res2a_branch2a_depth[0][0]
# __________________________________________________________________________________________________
# activation_2_color (Activation) (None, 239, 319, 64) 0           bn2a_branch2a_color[0][0]
# __________________________________________________________________________________________________
# activation_51_depth (Activation (None, 239, 319, 64) 0           bn2a_branch2a_depth[0][0]
# __________________________________________________________________________________________________
# res2a_branch2b_color (Conv2D)   (None, 239, 319, 64) 36928       activation_2_color[0][0]
# __________________________________________________________________________________________________
# res2a_branch2b_depth (Conv2D)   (None, 239, 319, 64) 36928       activation_51_depth[0][0]
# __________________________________________________________________________________________________
# bn2a_branch2b_color (BatchNorma (None, 239, 319, 64) 256         res2a_branch2b_color[0][0]
# __________________________________________________________________________________________________
# bn2a_branch2b_depth (BatchNorma (None, 239, 319, 64) 256         res2a_branch2b_depth[0][0]
# __________________________________________________________________________________________________
# activation_3_color (Activation) (None, 239, 319, 64) 0           bn2a_branch2b_color[0][0]
# __________________________________________________________________________________________________
# activation_52_depth (Activation (None, 239, 319, 64) 0           bn2a_branch2b_depth[0][0]
# __________________________________________________________________________________________________
# res2a_branch2c_color (Conv2D)   (None, 239, 319, 256 16640       activation_3_color[0][0]
# __________________________________________________________________________________________________
# res2a_branch1_color (Conv2D)    (None, 239, 319, 256 16640       max_pooling2d_1_color[0][0]
# __________________________________________________________________________________________________
# res2a_branch2c_depth (Conv2D)   (None, 239, 319, 256 16640       activation_52_depth[0][0]
# __________________________________________________________________________________________________
# res2a_branch1_depth (Conv2D)    (None, 239, 319, 256 16640       max_pooling2d_2_depth[0][0]
# __________________________________________________________________________________________________
# bn2a_branch2c_color (BatchNorma (None, 239, 319, 256 1024        res2a_branch2c_color[0][0]
# __________________________________________________________________________________________________
# bn2a_branch1_color (BatchNormal (None, 239, 319, 256 1024        res2a_branch1_color[0][0]
# __________________________________________________________________________________________________
# bn2a_branch2c_depth (BatchNorma (None, 239, 319, 256 1024        res2a_branch2c_depth[0][0]
# __________________________________________________________________________________________________
# bn2a_branch1_depth (BatchNormal (None, 239, 319, 256 1024        res2a_branch1_depth[0][0]
# __________________________________________________________________________________________________
# add_1_color (Add)               (None, 239, 319, 256 0           bn2a_branch2c_color[0][0]
#                                                                  bn2a_branch1_color[0][0]
# __________________________________________________________________________________________________
# add_17_depth (Add)              (None, 239, 319, 256 0           bn2a_branch2c_depth[0][0]
#                                                                  bn2a_branch1_depth[0][0]
# __________________________________________________________________________________________________
# activation_4_color (Activation) (None, 239, 319, 256 0           add_1_color[0][0]
# __________________________________________________________________________________________________
# activation_53_depth (Activation (None, 239, 319, 256 0           add_17_depth[0][0]
# __________________________________________________________________________________________________
# res2b_branch2a_color (Conv2D)   (None, 239, 319, 64) 16448       activation_4_color[0][0]
# __________________________________________________________________________________________________
# res2b_branch2a_depth (Conv2D)   (None, 239, 319, 64) 16448       activation_53_depth[0][0]
# __________________________________________________________________________________________________
# bn2b_branch2a_color (BatchNorma (None, 239, 319, 64) 256         res2b_branch2a_color[0][0]
# __________________________________________________________________________________________________
# bn2b_branch2a_depth (BatchNorma (None, 239, 319, 64) 256         res2b_branch2a_depth[0][0]
# __________________________________________________________________________________________________
# activation_5_color (Activation) (None, 239, 319, 64) 0           bn2b_branch2a_color[0][0]
# __________________________________________________________________________________________________
# activation_54_depth (Activation (None, 239, 319, 64) 0           bn2b_branch2a_depth[0][0]
# __________________________________________________________________________________________________
# res2b_branch2b_color (Conv2D)   (None, 239, 319, 64) 36928       activation_5_color[0][0]
# __________________________________________________________________________________________________
# res2b_branch2b_depth (Conv2D)   (None, 239, 319, 64) 36928       activation_54_depth[0][0]
# __________________________________________________________________________________________________
# bn2b_branch2b_color (BatchNorma (None, 239, 319, 64) 256         res2b_branch2b_color[0][0]
# __________________________________________________________________________________________________
# bn2b_branch2b_depth (BatchNorma (None, 239, 319, 64) 256         res2b_branch2b_depth[0][0]
# __________________________________________________________________________________________________
# activation_6_color (Activation) (None, 239, 319, 64) 0           bn2b_branch2b_color[0][0]
# __________________________________________________________________________________________________
# activation_55_depth (Activation (None, 239, 319, 64) 0           bn2b_branch2b_depth[0][0]
# __________________________________________________________________________________________________
# res2b_branch2c_color (Conv2D)   (None, 239, 319, 256 16640       activation_6_color[0][0]
# __________________________________________________________________________________________________
# res2b_branch2c_depth (Conv2D)   (None, 239, 319, 256 16640       activation_55_depth[0][0]
# __________________________________________________________________________________________________
# bn2b_branch2c_color (BatchNorma (None, 239, 319, 256 1024        res2b_branch2c_color[0][0]
# __________________________________________________________________________________________________
# bn2b_branch2c_depth (BatchNorma (None, 239, 319, 256 1024        res2b_branch2c_depth[0][0]
# __________________________________________________________________________________________________
# add_2_color (Add)               (None, 239, 319, 256 0           bn2b_branch2c_color[0][0]
#                                                                  activation_4_color[0][0]
# __________________________________________________________________________________________________
# add_18_depth (Add)              (None, 239, 319, 256 0           bn2b_branch2c_depth[0][0]
#                                                                  activation_53_depth[0][0]
# __________________________________________________________________________________________________
# activation_7_color (Activation) (None, 239, 319, 256 0           add_2_color[0][0]
# __________________________________________________________________________________________________
# activation_56_depth (Activation (None, 239, 319, 256 0           add_18_depth[0][0]
# __________________________________________________________________________________________________
# res2c_branch2a_color (Conv2D)   (None, 239, 319, 64) 16448       activation_7_color[0][0]
# __________________________________________________________________________________________________
# res2c_branch2a_depth (Conv2D)   (None, 239, 319, 64) 16448       activation_56_depth[0][0]
# __________________________________________________________________________________________________
# bn2c_branch2a_color (BatchNorma (None, 239, 319, 64) 256         res2c_branch2a_color[0][0]
# __________________________________________________________________________________________________
# bn2c_branch2a_depth (BatchNorma (None, 239, 319, 64) 256         res2c_branch2a_depth[0][0]
# __________________________________________________________________________________________________
# activation_8_color (Activation) (None, 239, 319, 64) 0           bn2c_branch2a_color[0][0]
# __________________________________________________________________________________________________
# activation_57_depth (Activation (None, 239, 319, 64) 0           bn2c_branch2a_depth[0][0]
# __________________________________________________________________________________________________
# res2c_branch2b_color (Conv2D)   (None, 239, 319, 64) 36928       activation_8_color[0][0]
# __________________________________________________________________________________________________
# res2c_branch2b_depth (Conv2D)   (None, 239, 319, 64) 36928       activation_57_depth[0][0]
# __________________________________________________________________________________________________
# bn2c_branch2b_color (BatchNorma (None, 239, 319, 64) 256         res2c_branch2b_color[0][0]
# __________________________________________________________________________________________________
# bn2c_branch2b_depth (BatchNorma (None, 239, 319, 64) 256         res2c_branch2b_depth[0][0]
# __________________________________________________________________________________________________
# activation_9_color (Activation) (None, 239, 319, 64) 0           bn2c_branch2b_color[0][0]
# __________________________________________________________________________________________________
# activation_58_depth (Activation (None, 239, 319, 64) 0           bn2c_branch2b_depth[0][0]
# __________________________________________________________________________________________________
# res2c_branch2c_color (Conv2D)   (None, 239, 319, 256 16640       activation_9_color[0][0]
# __________________________________________________________________________________________________
# res2c_branch2c_depth (Conv2D)   (None, 239, 319, 256 16640       activation_58_depth[0][0]
# __________________________________________________________________________________________________
# bn2c_branch2c_color (BatchNorma (None, 239, 319, 256 1024        res2c_branch2c_color[0][0]
# __________________________________________________________________________________________________
# bn2c_branch2c_depth (BatchNorma (None, 239, 319, 256 1024        res2c_branch2c_depth[0][0]
# __________________________________________________________________________________________________
# add_3_color (Add)               (None, 239, 319, 256 0           bn2c_branch2c_color[0][0]
#                                                                  activation_7_color[0][0]
# __________________________________________________________________________________________________
# add_19_depth (Add)              (None, 239, 319, 256 0           bn2c_branch2c_depth[0][0]
#                                                                  activation_56_depth[0][0]
# __________________________________________________________________________________________________
# activation_10_color (Activation (None, 239, 319, 256 0           add_3_color[0][0]
# __________________________________________________________________________________________________
# activation_59_depth (Activation (None, 239, 319, 256 0           add_19_depth[0][0]
# __________________________________________________________________________________________________
# res3a_branch2a_color (Conv2D)   (None, 120, 160, 128 32896       activation_10_color[0][0]
# __________________________________________________________________________________________________
# res3a_branch2a_depth (Conv2D)   (None, 120, 160, 128 32896       activation_59_depth[0][0]
# __________________________________________________________________________________________________
# bn3a_branch2a_color (BatchNorma (None, 120, 160, 128 512         res3a_branch2a_color[0][0]
# __________________________________________________________________________________________________
# bn3a_branch2a_depth (BatchNorma (None, 120, 160, 128 512         res3a_branch2a_depth[0][0]
# __________________________________________________________________________________________________
# activation_11_color (Activation (None, 120, 160, 128 0           bn3a_branch2a_color[0][0]
# __________________________________________________________________________________________________
# activation_60_depth (Activation (None, 120, 160, 128 0           bn3a_branch2a_depth[0][0]
# __________________________________________________________________________________________________
# res3a_branch2b_color (Conv2D)   (None, 120, 160, 128 147584      activation_11_color[0][0]
# __________________________________________________________________________________________________
# res3a_branch2b_depth (Conv2D)   (None, 120, 160, 128 147584      activation_60_depth[0][0]
# __________________________________________________________________________________________________
# bn3a_branch2b_color (BatchNorma (None, 120, 160, 128 512         res3a_branch2b_color[0][0]
# __________________________________________________________________________________________________
# bn3a_branch2b_depth (BatchNorma (None, 120, 160, 128 512         res3a_branch2b_depth[0][0]
# __________________________________________________________________________________________________
# activation_12_color (Activation (None, 120, 160, 128 0           bn3a_branch2b_color[0][0]
# __________________________________________________________________________________________________
# activation_61_depth (Activation (None, 120, 160, 128 0           bn3a_branch2b_depth[0][0]
# __________________________________________________________________________________________________
# res3a_branch2c_color (Conv2D)   (None, 120, 160, 512 66048       activation_12_color[0][0]
# __________________________________________________________________________________________________
# res3a_branch1_color (Conv2D)    (None, 120, 160, 512 131584      activation_10_color[0][0]
# __________________________________________________________________________________________________
# res3a_branch2c_depth (Conv2D)   (None, 120, 160, 512 66048       activation_61_depth[0][0]
# __________________________________________________________________________________________________
# res3a_branch1_depth (Conv2D)    (None, 120, 160, 512 131584      activation_59_depth[0][0]
# __________________________________________________________________________________________________
# bn3a_branch2c_color (BatchNorma (None, 120, 160, 512 2048        res3a_branch2c_color[0][0]
# __________________________________________________________________________________________________
# bn3a_branch1_color (BatchNormal (None, 120, 160, 512 2048        res3a_branch1_color[0][0]
# __________________________________________________________________________________________________
# bn3a_branch2c_depth (BatchNorma (None, 120, 160, 512 2048        res3a_branch2c_depth[0][0]
# __________________________________________________________________________________________________
# bn3a_branch1_depth (BatchNormal (None, 120, 160, 512 2048        res3a_branch1_depth[0][0]
# __________________________________________________________________________________________________
# add_4_color (Add)               (None, 120, 160, 512 0           bn3a_branch2c_color[0][0]
#                                                                  bn3a_branch1_color[0][0]
# __________________________________________________________________________________________________
# add_20_depth (Add)              (None, 120, 160, 512 0           bn3a_branch2c_depth[0][0]
#                                                                  bn3a_branch1_depth[0][0]
# __________________________________________________________________________________________________
# activation_13_color (Activation (None, 120, 160, 512 0           add_4_color[0][0]
# __________________________________________________________________________________________________
# activation_62_depth (Activation (None, 120, 160, 512 0           add_20_depth[0][0]
# __________________________________________________________________________________________________
# res3b_branch2a_color (Conv2D)   (None, 120, 160, 128 65664       activation_13_color[0][0]
# __________________________________________________________________________________________________
# res3b_branch2a_depth (Conv2D)   (None, 120, 160, 128 65664       activation_62_depth[0][0]
# __________________________________________________________________________________________________
# bn3b_branch2a_color (BatchNorma (None, 120, 160, 128 512         res3b_branch2a_color[0][0]
# __________________________________________________________________________________________________
# bn3b_branch2a_depth (BatchNorma (None, 120, 160, 128 512         res3b_branch2a_depth[0][0]
# __________________________________________________________________________________________________
# activation_14_color (Activation (None, 120, 160, 128 0           bn3b_branch2a_color[0][0]
# __________________________________________________________________________________________________
# activation_63_depth (Activation (None, 120, 160, 128 0           bn3b_branch2a_depth[0][0]
# __________________________________________________________________________________________________
# res3b_branch2b_color (Conv2D)   (None, 120, 160, 128 147584      activation_14_color[0][0]
# __________________________________________________________________________________________________
# res3b_branch2b_depth (Conv2D)   (None, 120, 160, 128 147584      activation_63_depth[0][0]
# __________________________________________________________________________________________________
# bn3b_branch2b_color (BatchNorma (None, 120, 160, 128 512         res3b_branch2b_color[0][0]
# __________________________________________________________________________________________________
# bn3b_branch2b_depth (BatchNorma (None, 120, 160, 128 512         res3b_branch2b_depth[0][0]
# __________________________________________________________________________________________________
# activation_15_color (Activation (None, 120, 160, 128 0           bn3b_branch2b_color[0][0]
# __________________________________________________________________________________________________
# activation_64_depth (Activation (None, 120, 160, 128 0           bn3b_branch2b_depth[0][0]
# __________________________________________________________________________________________________
# res3b_branch2c_color (Conv2D)   (None, 120, 160, 512 66048       activation_15_color[0][0]
# __________________________________________________________________________________________________
# res3b_branch2c_depth (Conv2D)   (None, 120, 160, 512 66048       activation_64_depth[0][0]
# __________________________________________________________________________________________________
# bn3b_branch2c_color (BatchNorma (None, 120, 160, 512 2048        res3b_branch2c_color[0][0]
# __________________________________________________________________________________________________
# bn3b_branch2c_depth (BatchNorma (None, 120, 160, 512 2048        res3b_branch2c_depth[0][0]
# __________________________________________________________________________________________________
# add_5_color (Add)               (None, 120, 160, 512 0           bn3b_branch2c_color[0][0]
#                                                                  activation_13_color[0][0]
# __________________________________________________________________________________________________
# add_21_depth (Add)              (None, 120, 160, 512 0           bn3b_branch2c_depth[0][0]
#                                                                  activation_62_depth[0][0]
# __________________________________________________________________________________________________
# activation_16_color (Activation (None, 120, 160, 512 0           add_5_color[0][0]
# __________________________________________________________________________________________________
# activation_65_depth (Activation (None, 120, 160, 512 0           add_21_depth[0][0]
# __________________________________________________________________________________________________
# res3c_branch2a_color (Conv2D)   (None, 120, 160, 128 65664       activation_16_color[0][0]
# __________________________________________________________________________________________________
# res3c_branch2a_depth (Conv2D)   (None, 120, 160, 128 65664       activation_65_depth[0][0]
# __________________________________________________________________________________________________
# bn3c_branch2a_color (BatchNorma (None, 120, 160, 128 512         res3c_branch2a_color[0][0]
# __________________________________________________________________________________________________
# bn3c_branch2a_depth (BatchNorma (None, 120, 160, 128 512         res3c_branch2a_depth[0][0]
# __________________________________________________________________________________________________
# activation_17_color (Activation (None, 120, 160, 128 0           bn3c_branch2a_color[0][0]
# __________________________________________________________________________________________________
# activation_66_depth (Activation (None, 120, 160, 128 0           bn3c_branch2a_depth[0][0]
# __________________________________________________________________________________________________
# res3c_branch2b_color (Conv2D)   (None, 120, 160, 128 147584      activation_17_color[0][0]
# __________________________________________________________________________________________________
# res3c_branch2b_depth (Conv2D)   (None, 120, 160, 128 147584      activation_66_depth[0][0]
# __________________________________________________________________________________________________
# bn3c_branch2b_color (BatchNorma (None, 120, 160, 128 512         res3c_branch2b_color[0][0]
# __________________________________________________________________________________________________
# bn3c_branch2b_depth (BatchNorma (None, 120, 160, 128 512         res3c_branch2b_depth[0][0]
# __________________________________________________________________________________________________
# activation_18_color (Activation (None, 120, 160, 128 0           bn3c_branch2b_color[0][0]
# __________________________________________________________________________________________________
# activation_67_depth (Activation (None, 120, 160, 128 0           bn3c_branch2b_depth[0][0]
# __________________________________________________________________________________________________
# res3c_branch2c_color (Conv2D)   (None, 120, 160, 512 66048       activation_18_color[0][0]
# __________________________________________________________________________________________________
# res3c_branch2c_depth (Conv2D)   (None, 120, 160, 512 66048       activation_67_depth[0][0]
# __________________________________________________________________________________________________
# bn3c_branch2c_color (BatchNorma (None, 120, 160, 512 2048        res3c_branch2c_color[0][0]
# __________________________________________________________________________________________________
# bn3c_branch2c_depth (BatchNorma (None, 120, 160, 512 2048        res3c_branch2c_depth[0][0]
# __________________________________________________________________________________________________
# add_6_color (Add)               (None, 120, 160, 512 0           bn3c_branch2c_color[0][0]
#                                                                  activation_16_color[0][0]
# __________________________________________________________________________________________________
# add_22_depth (Add)              (None, 120, 160, 512 0           bn3c_branch2c_depth[0][0]
#                                                                  activation_65_depth[0][0]
# __________________________________________________________________________________________________
# activation_19_color (Activation (None, 120, 160, 512 0           add_6_color[0][0]
# __________________________________________________________________________________________________
# activation_68_depth (Activation (None, 120, 160, 512 0           add_22_depth[0][0]
# __________________________________________________________________________________________________
# res3d_branch2a_color (Conv2D)   (None, 120, 160, 128 65664       activation_19_color[0][0]
# __________________________________________________________________________________________________
# res3d_branch2a_depth (Conv2D)   (None, 120, 160, 128 65664       activation_68_depth[0][0]
# __________________________________________________________________________________________________
# bn3d_branch2a_color (BatchNorma (None, 120, 160, 128 512         res3d_branch2a_color[0][0]
# __________________________________________________________________________________________________
# bn3d_branch2a_depth (BatchNorma (None, 120, 160, 128 512         res3d_branch2a_depth[0][0]
# __________________________________________________________________________________________________
# activation_20_color (Activation (None, 120, 160, 128 0           bn3d_branch2a_color[0][0]
# __________________________________________________________________________________________________
# activation_69_depth (Activation (None, 120, 160, 128 0           bn3d_branch2a_depth[0][0]
# __________________________________________________________________________________________________
# res3d_branch2b_color (Conv2D)   (None, 120, 160, 128 147584      activation_20_color[0][0]
# __________________________________________________________________________________________________
# res3d_branch2b_depth (Conv2D)   (None, 120, 160, 128 147584      activation_69_depth[0][0]
# __________________________________________________________________________________________________
# bn3d_branch2b_color (BatchNorma (None, 120, 160, 128 512         res3d_branch2b_color[0][0]
# __________________________________________________________________________________________________
# bn3d_branch2b_depth (BatchNorma (None, 120, 160, 128 512         res3d_branch2b_depth[0][0]
# __________________________________________________________________________________________________
# activation_21_color (Activation (None, 120, 160, 128 0           bn3d_branch2b_color[0][0]
# __________________________________________________________________________________________________
# activation_70_depth (Activation (None, 120, 160, 128 0           bn3d_branch2b_depth[0][0]
# __________________________________________________________________________________________________
# res3d_branch2c_color (Conv2D)   (None, 120, 160, 512 66048       activation_21_color[0][0]
# __________________________________________________________________________________________________
# res3d_branch2c_depth (Conv2D)   (None, 120, 160, 512 66048       activation_70_depth[0][0]
# __________________________________________________________________________________________________
# bn3d_branch2c_color (BatchNorma (None, 120, 160, 512 2048        res3d_branch2c_color[0][0]
# __________________________________________________________________________________________________
# bn3d_branch2c_depth (BatchNorma (None, 120, 160, 512 2048        res3d_branch2c_depth[0][0]
# __________________________________________________________________________________________________
# add_7_color (Add)               (None, 120, 160, 512 0           bn3d_branch2c_color[0][0]
#                                                                  activation_19_color[0][0]
# __________________________________________________________________________________________________
# add_23_depth (Add)              (None, 120, 160, 512 0           bn3d_branch2c_depth[0][0]
#                                                                  activation_68_depth[0][0]
# __________________________________________________________________________________________________
# activation_22_color (Activation (None, 120, 160, 512 0           add_7_color[0][0]
# __________________________________________________________________________________________________
# activation_71_depth (Activation (None, 120, 160, 512 0           add_23_depth[0][0]
# __________________________________________________________________________________________________
# res4a_branch2a_color (Conv2D)   (None, 60, 80, 256)  131328      activation_22_color[0][0]
# __________________________________________________________________________________________________
# res4a_branch2a_depth (Conv2D)   (None, 60, 80, 256)  131328      activation_71_depth[0][0]
# __________________________________________________________________________________________________
# bn4a_branch2a_color (BatchNorma (None, 60, 80, 256)  1024        res4a_branch2a_color[0][0]
# __________________________________________________________________________________________________
# bn4a_branch2a_depth (BatchNorma (None, 60, 80, 256)  1024        res4a_branch2a_depth[0][0]
# __________________________________________________________________________________________________
# activation_23_color (Activation (None, 60, 80, 256)  0           bn4a_branch2a_color[0][0]
# __________________________________________________________________________________________________
# activation_72_depth (Activation (None, 60, 80, 256)  0           bn4a_branch2a_depth[0][0]
# __________________________________________________________________________________________________
# res4a_branch2b_color (Conv2D)   (None, 60, 80, 256)  590080      activation_23_color[0][0]
# __________________________________________________________________________________________________
# res4a_branch2b_depth (Conv2D)   (None, 60, 80, 256)  590080      activation_72_depth[0][0]
# __________________________________________________________________________________________________
# bn4a_branch2b_color (BatchNorma (None, 60, 80, 256)  1024        res4a_branch2b_color[0][0]
# __________________________________________________________________________________________________
# bn4a_branch2b_depth (BatchNorma (None, 60, 80, 256)  1024        res4a_branch2b_depth[0][0]
# __________________________________________________________________________________________________
# activation_24_color (Activation (None, 60, 80, 256)  0           bn4a_branch2b_color[0][0]
# __________________________________________________________________________________________________
# activation_73_depth (Activation (None, 60, 80, 256)  0           bn4a_branch2b_depth[0][0]
# __________________________________________________________________________________________________
# res4a_branch2c_color (Conv2D)   (None, 60, 80, 1024) 263168      activation_24_color[0][0]
# __________________________________________________________________________________________________
# res4a_branch1_color (Conv2D)    (None, 60, 80, 1024) 525312      activation_22_color[0][0]
# __________________________________________________________________________________________________
# res4a_branch2c_depth (Conv2D)   (None, 60, 80, 1024) 263168      activation_73_depth[0][0]
# __________________________________________________________________________________________________
# res4a_branch1_depth (Conv2D)    (None, 60, 80, 1024) 525312      activation_71_depth[0][0]
# __________________________________________________________________________________________________
# bn4a_branch2c_color (BatchNorma (None, 60, 80, 1024) 4096        res4a_branch2c_color[0][0]
# __________________________________________________________________________________________________
# bn4a_branch1_color (BatchNormal (None, 60, 80, 1024) 4096        res4a_branch1_color[0][0]
# __________________________________________________________________________________________________
# bn4a_branch2c_depth (BatchNorma (None, 60, 80, 1024) 4096        res4a_branch2c_depth[0][0]
# __________________________________________________________________________________________________
# bn4a_branch1_depth (BatchNormal (None, 60, 80, 1024) 4096        res4a_branch1_depth[0][0]
# __________________________________________________________________________________________________
# add_8_color (Add)               (None, 60, 80, 1024) 0           bn4a_branch2c_color[0][0]
#                                                                  bn4a_branch1_color[0][0]
# __________________________________________________________________________________________________
# add_24_depth (Add)              (None, 60, 80, 1024) 0           bn4a_branch2c_depth[0][0]
#                                                                  bn4a_branch1_depth[0][0]
# __________________________________________________________________________________________________
# activation_25_color (Activation (None, 60, 80, 1024) 0           add_8_color[0][0]
# __________________________________________________________________________________________________
# activation_74_depth (Activation (None, 60, 80, 1024) 0           add_24_depth[0][0]
# __________________________________________________________________________________________________
# res4b_branch2a_color (Conv2D)   (None, 60, 80, 256)  262400      activation_25_color[0][0]
# __________________________________________________________________________________________________
# res4b_branch2a_depth (Conv2D)   (None, 60, 80, 256)  262400      activation_74_depth[0][0]
# __________________________________________________________________________________________________
# bn4b_branch2a_color (BatchNorma (None, 60, 80, 256)  1024        res4b_branch2a_color[0][0]
# __________________________________________________________________________________________________
# bn4b_branch2a_depth (BatchNorma (None, 60, 80, 256)  1024        res4b_branch2a_depth[0][0]
# __________________________________________________________________________________________________
# activation_26_color (Activation (None, 60, 80, 256)  0           bn4b_branch2a_color[0][0]
# __________________________________________________________________________________________________
# activation_75_depth (Activation (None, 60, 80, 256)  0           bn4b_branch2a_depth[0][0]
# __________________________________________________________________________________________________
# res4b_branch2b_color (Conv2D)   (None, 60, 80, 256)  590080      activation_26_color[0][0]
# __________________________________________________________________________________________________
# res4b_branch2b_depth (Conv2D)   (None, 60, 80, 256)  590080      activation_75_depth[0][0]
# __________________________________________________________________________________________________
# bn4b_branch2b_color (BatchNorma (None, 60, 80, 256)  1024        res4b_branch2b_color[0][0]
# __________________________________________________________________________________________________
# bn4b_branch2b_depth (BatchNorma (None, 60, 80, 256)  1024        res4b_branch2b_depth[0][0]
# __________________________________________________________________________________________________
# activation_27_color (Activation (None, 60, 80, 256)  0           bn4b_branch2b_color[0][0]
# __________________________________________________________________________________________________
# activation_76_depth (Activation (None, 60, 80, 256)  0           bn4b_branch2b_depth[0][0]
# __________________________________________________________________________________________________
# res4b_branch2c_color (Conv2D)   (None, 60, 80, 1024) 263168      activation_27_color[0][0]
# __________________________________________________________________________________________________
# res4b_branch2c_depth (Conv2D)   (None, 60, 80, 1024) 263168      activation_76_depth[0][0]
# __________________________________________________________________________________________________
# bn4b_branch2c_color (BatchNorma (None, 60, 80, 1024) 4096        res4b_branch2c_color[0][0]
# __________________________________________________________________________________________________
# bn4b_branch2c_depth (BatchNorma (None, 60, 80, 1024) 4096        res4b_branch2c_depth[0][0]
# __________________________________________________________________________________________________
# add_9_color (Add)               (None, 60, 80, 1024) 0           bn4b_branch2c_color[0][0]
#                                                                  activation_25_color[0][0]
# __________________________________________________________________________________________________
# add_25_depth (Add)              (None, 60, 80, 1024) 0           bn4b_branch2c_depth[0][0]
#                                                                  activation_74_depth[0][0]
# __________________________________________________________________________________________________
# activation_28_color (Activation (None, 60, 80, 1024) 0           add_9_color[0][0]
# __________________________________________________________________________________________________
# activation_77_depth (Activation (None, 60, 80, 1024) 0           add_25_depth[0][0]
# __________________________________________________________________________________________________
# res4c_branch2a_color (Conv2D)   (None, 60, 80, 256)  262400      activation_28_color[0][0]
# __________________________________________________________________________________________________
# res4c_branch2a_depth (Conv2D)   (None, 60, 80, 256)  262400      activation_77_depth[0][0]
# __________________________________________________________________________________________________
# bn4c_branch2a_color (BatchNorma (None, 60, 80, 256)  1024        res4c_branch2a_color[0][0]
# __________________________________________________________________________________________________
# bn4c_branch2a_depth (BatchNorma (None, 60, 80, 256)  1024        res4c_branch2a_depth[0][0]
# __________________________________________________________________________________________________
# activation_29_color (Activation (None, 60, 80, 256)  0           bn4c_branch2a_color[0][0]
# __________________________________________________________________________________________________
# activation_78_depth (Activation (None, 60, 80, 256)  0           bn4c_branch2a_depth[0][0]
# __________________________________________________________________________________________________
# res4c_branch2b_color (Conv2D)   (None, 60, 80, 256)  590080      activation_29_color[0][0]
# __________________________________________________________________________________________________
# res4c_branch2b_depth (Conv2D)   (None, 60, 80, 256)  590080      activation_78_depth[0][0]
# __________________________________________________________________________________________________
# bn4c_branch2b_color (BatchNorma (None, 60, 80, 256)  1024        res4c_branch2b_color[0][0]
# __________________________________________________________________________________________________
# bn4c_branch2b_depth (BatchNorma (None, 60, 80, 256)  1024        res4c_branch2b_depth[0][0]
# __________________________________________________________________________________________________
# activation_30_color (Activation (None, 60, 80, 256)  0           bn4c_branch2b_color[0][0]
# __________________________________________________________________________________________________
# activation_79_depth (Activation (None, 60, 80, 256)  0           bn4c_branch2b_depth[0][0]
# __________________________________________________________________________________________________
# res4c_branch2c_color (Conv2D)   (None, 60, 80, 1024) 263168      activation_30_color[0][0]
# __________________________________________________________________________________________________
# res4c_branch2c_depth (Conv2D)   (None, 60, 80, 1024) 263168      activation_79_depth[0][0]
# __________________________________________________________________________________________________
# bn4c_branch2c_color (BatchNorma (None, 60, 80, 1024) 4096        res4c_branch2c_color[0][0]
# __________________________________________________________________________________________________
# bn4c_branch2c_depth (BatchNorma (None, 60, 80, 1024) 4096        res4c_branch2c_depth[0][0]
# __________________________________________________________________________________________________
# add_10_color (Add)              (None, 60, 80, 1024) 0           bn4c_branch2c_color[0][0]
#                                                                  activation_28_color[0][0]
# __________________________________________________________________________________________________
# add_26_depth (Add)              (None, 60, 80, 1024) 0           bn4c_branch2c_depth[0][0]
#                                                                  activation_77_depth[0][0]
# __________________________________________________________________________________________________
# activation_31_color (Activation (None, 60, 80, 1024) 0           add_10_color[0][0]
# __________________________________________________________________________________________________
# activation_80_depth (Activation (None, 60, 80, 1024) 0           add_26_depth[0][0]
# __________________________________________________________________________________________________
# res4d_branch2a_color (Conv2D)   (None, 60, 80, 256)  262400      activation_31_color[0][0]
# __________________________________________________________________________________________________
# res4d_branch2a_depth (Conv2D)   (None, 60, 80, 256)  262400      activation_80_depth[0][0]
# __________________________________________________________________________________________________
# bn4d_branch2a_color (BatchNorma (None, 60, 80, 256)  1024        res4d_branch2a_color[0][0]
# __________________________________________________________________________________________________
# bn4d_branch2a_depth (BatchNorma (None, 60, 80, 256)  1024        res4d_branch2a_depth[0][0]
# __________________________________________________________________________________________________
# activation_32_color (Activation (None, 60, 80, 256)  0           bn4d_branch2a_color[0][0]
# __________________________________________________________________________________________________
# activation_81_depth (Activation (None, 60, 80, 256)  0           bn4d_branch2a_depth[0][0]
# __________________________________________________________________________________________________
# res4d_branch2b_color (Conv2D)   (None, 60, 80, 256)  590080      activation_32_color[0][0]
# ...
# __________________________________________________________________________________________________
# add_29_depth (Add)              (None, 60, 80, 1024) 0           bn4f_branch2c_depth[0][0]
#                                                                  activation_86_depth[0][0]
# __________________________________________________________________________________________________
# activation_40_color (Activation (None, 60, 80, 1024) 0           add_13_color[0][0]
# __________________________________________________________________________________________________
# activation_89_depth (Activation (None, 60, 80, 1024) 0           add_29_depth[0][0]
# __________________________________________________________________________________________________
# res5a_branch2a_color (Conv2D)   (None, 30, 40, 512)  524800      activation_40_color[0][0]
# __________________________________________________________________________________________________
# res5a_branch2a_depth (Conv2D)   (None, 30, 40, 512)  524800      activation_89_depth[0][0]
# __________________________________________________________________________________________________
# bn5a_branch2a_color (BatchNorma (None, 30, 40, 512)  2048        res5a_branch2a_color[0][0]
# __________________________________________________________________________________________________
# bn5a_branch2a_depth (BatchNorma (None, 30, 40, 512)  2048        res5a_branch2a_depth[0][0]
# __________________________________________________________________________________________________
# activation_41_color (Activation (None, 30, 40, 512)  0           bn5a_branch2a_color[0][0]
# __________________________________________________________________________________________________
# activation_90_depth (Activation (None, 30, 40, 512)  0           bn5a_branch2a_depth[0][0]
# __________________________________________________________________________________________________
# res5a_branch2b_color (Conv2D)   (None, 30, 40, 512)  2359808     activation_41_color[0][0]
# __________________________________________________________________________________________________
# res5a_branch2b_depth (Conv2D)   (None, 30, 40, 512)  2359808     activation_90_depth[0][0]
# __________________________________________________________________________________________________
# bn5a_branch2b_color (BatchNorma (None, 30, 40, 512)  2048        res5a_branch2b_color[0][0]
# __________________________________________________________________________________________________
# bn5a_branch2b_depth (BatchNorma (None, 30, 40, 512)  2048        res5a_branch2b_depth[0][0]
# __________________________________________________________________________________________________
# activation_42_color (Activation (None, 30, 40, 512)  0           bn5a_branch2b_color[0][0]
# __________________________________________________________________________________________________
# activation_91_depth (Activation (None, 30, 40, 512)  0           bn5a_branch2b_depth[0][0]
# __________________________________________________________________________________________________
# res5a_branch2c_color (Conv2D)   (None, 30, 40, 2048) 1050624     activation_42_color[0][0]
# __________________________________________________________________________________________________
# res5a_branch1_color (Conv2D)    (None, 30, 40, 2048) 2099200     activation_40_color[0][0]
# __________________________________________________________________________________________________
# res5a_branch2c_depth (Conv2D)   (None, 30, 40, 2048) 1050624     activation_91_depth[0][0]
# __________________________________________________________________________________________________
# res5a_branch1_depth (Conv2D)    (None, 30, 40, 2048) 2099200     activation_89_depth[0][0]
# __________________________________________________________________________________________________
# bn5a_branch2c_color (BatchNorma (None, 30, 40, 2048) 8192        res5a_branch2c_color[0][0]
# __________________________________________________________________________________________________
# bn5a_branch1_color (BatchNormal (None, 30, 40, 2048) 8192        res5a_branch1_color[0][0]
# __________________________________________________________________________________________________
# bn5a_branch2c_depth (BatchNorma (None, 30, 40, 2048) 8192        res5a_branch2c_depth[0][0]
# __________________________________________________________________________________________________
# bn5a_branch1_depth (BatchNormal (None, 30, 40, 2048) 8192        res5a_branch1_depth[0][0]
# __________________________________________________________________________________________________
# add_14_color (Add)              (None, 30, 40, 2048) 0           bn5a_branch2c_color[0][0]
#                                                                  bn5a_branch1_color[0][0]
# __________________________________________________________________________________________________
# add_30_depth (Add)              (None, 30, 40, 2048) 0           bn5a_branch2c_depth[0][0]
#                                                                  bn5a_branch1_depth[0][0]
# __________________________________________________________________________________________________
# activation_43_color (Activation (None, 30, 40, 2048) 0           add_14_color[0][0]
# __________________________________________________________________________________________________
# activation_92_depth (Activation (None, 30, 40, 2048) 0           add_30_depth[0][0]
# __________________________________________________________________________________________________
# res5b_branch2a_color (Conv2D)   (None, 30, 40, 512)  1049088     activation_43_color[0][0]
# __________________________________________________________________________________________________
# res5b_branch2a_depth (Conv2D)   (None, 30, 40, 512)  1049088     activation_92_depth[0][0]
# __________________________________________________________________________________________________
# bn5b_branch2a_color (BatchNorma (None, 30, 40, 512)  2048        res5b_branch2a_color[0][0]
# __________________________________________________________________________________________________
# bn5b_branch2a_depth (BatchNorma (None, 30, 40, 512)  2048        res5b_branch2a_depth[0][0]
# __________________________________________________________________________________________________
# activation_44_color (Activation (None, 30, 40, 512)  0           bn5b_branch2a_color[0][0]
# __________________________________________________________________________________________________
# activation_93_depth (Activation (None, 30, 40, 512)  0           bn5b_branch2a_depth[0][0]
# __________________________________________________________________________________________________
# res5b_branch2b_color (Conv2D)   (None, 30, 40, 512)  2359808     activation_44_color[0][0]
# __________________________________________________________________________________________________
# res5b_branch2b_depth (Conv2D)   (None, 30, 40, 512)  2359808     activation_93_depth[0][0]
# __________________________________________________________________________________________________
# bn5b_branch2b_color (BatchNorma (None, 30, 40, 512)  2048        res5b_branch2b_color[0][0]
# __________________________________________________________________________________________________
# bn5b_branch2b_depth (BatchNorma (None, 30, 40, 512)  2048        res5b_branch2b_depth[0][0]
# __________________________________________________________________________________________________
# activation_45_color (Activation (None, 30, 40, 512)  0           bn5b_branch2b_color[0][0]
# __________________________________________________________________________________________________
# activation_94_depth (Activation (None, 30, 40, 512)  0           bn5b_branch2b_depth[0][0]
# __________________________________________________________________________________________________
# res5b_branch2c_color (Conv2D)   (None, 30, 40, 2048) 1050624     activation_45_color[0][0]
# __________________________________________________________________________________________________
# res5b_branch2c_depth (Conv2D)   (None, 30, 40, 2048) 1050624     activation_94_depth[0][0]
# __________________________________________________________________________________________________
# bn5b_branch2c_color (BatchNorma (None, 30, 40, 2048) 8192        res5b_branch2c_color[0][0]
# __________________________________________________________________________________________________
# bn5b_branch2c_depth (BatchNorma (None, 30, 40, 2048) 8192        res5b_branch2c_depth[0][0]
# __________________________________________________________________________________________________
# add_15_color (Add)              (None, 30, 40, 2048) 0           bn5b_branch2c_color[0][0]
#                                                                  activation_43_color[0][0]
# __________________________________________________________________________________________________
# add_31_depth (Add)              (None, 30, 40, 2048) 0           bn5b_branch2c_depth[0][0]
#                                                                  activation_92_depth[0][0]
# __________________________________________________________________________________________________
# activation_46_color (Activation (None, 30, 40, 2048) 0           add_15_color[0][0]
# __________________________________________________________________________________________________
# activation_95_depth (Activation (None, 30, 40, 2048) 0           add_31_depth[0][0]
# __________________________________________________________________________________________________
# res5c_branch2a_color (Conv2D)   (None, 30, 40, 512)  1049088     activation_46_color[0][0]
# __________________________________________________________________________________________________
# res5c_branch2a_depth (Conv2D)   (None, 30, 40, 512)  1049088     activation_95_depth[0][0]
# __________________________________________________________________________________________________
# bn5c_branch2a_color (BatchNorma (None, 30, 40, 512)  2048        res5c_branch2a_color[0][0]
# __________________________________________________________________________________________________
# bn5c_branch2a_depth (BatchNorma (None, 30, 40, 512)  2048        res5c_branch2a_depth[0][0]
# __________________________________________________________________________________________________
# activation_47_color (Activation (None, 30, 40, 512)  0           bn5c_branch2a_color[0][0]
# __________________________________________________________________________________________________
# activation_96_depth (Activation (None, 30, 40, 512)  0           bn5c_branch2a_depth[0][0]
# __________________________________________________________________________________________________
# res5c_branch2b_color (Conv2D)   (None, 30, 40, 512)  2359808     activation_47_color[0][0]
# __________________________________________________________________________________________________
# res5c_branch2b_depth (Conv2D)   (None, 30, 40, 512)  2359808     activation_96_depth[0][0]
# __________________________________________________________________________________________________
# bn5c_branch2b_color (BatchNorma (None, 30, 40, 512)  2048        res5c_branch2b_color[0][0]
# __________________________________________________________________________________________________
# bn5c_branch2b_depth (BatchNorma (None, 30, 40, 512)  2048        res5c_branch2b_depth[0][0]
# __________________________________________________________________________________________________
# activation_48_color (Activation (None, 30, 40, 512)  0           bn5c_branch2b_color[0][0]
# __________________________________________________________________________________________________
# activation_97_depth (Activation (None, 30, 40, 512)  0           bn5c_branch2b_depth[0][0]
# __________________________________________________________________________________________________
# res5c_branch2c_color (Conv2D)   (None, 30, 40, 2048) 1050624     activation_48_color[0][0]
# __________________________________________________________________________________________________
# res5c_branch2c_depth (Conv2D)   (None, 30, 40, 2048) 1050624     activation_97_depth[0][0]
# __________________________________________________________________________________________________
# bn5c_branch2c_color (BatchNorma (None, 30, 40, 2048) 8192        res5c_branch2c_color[0][0]
# __________________________________________________________________________________________________
# bn5c_branch2c_depth (BatchNorma (None, 30, 40, 2048) 8192        res5c_branch2c_depth[0][0]
# __________________________________________________________________________________________________
# add_16_color (Add)              (None, 30, 40, 2048) 0           bn5c_branch2c_color[0][0]
#                                                                  activation_46_color[0][0]
# __________________________________________________________________________________________________
# add_32_depth (Add)              (None, 30, 40, 2048) 0           bn5c_branch2c_depth[0][0]
#                                                                  activation_95_depth[0][0]
# __________________________________________________________________________________________________
# activation_49_color (Activation (None, 30, 40, 2048) 0           add_16_color[0][0]
# __________________________________________________________________________________________________
# activation_98_depth (Activation (None, 30, 40, 2048) 0           add_32_depth[0][0]
# __________________________________________________________________________________________________
# Addydoo (Concatenate)           (None, 30, 40, 4096) 0           activation_49_color[0][0]
#                                                                  activation_98_depth[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_1 (UpSampling2D)  (None, 60, 80, 4096) 0           Addydoo[0][0]
# __________________________________________________________________________________________________
# Frank (Conv2D)                  (None, 60, 80, 512)  18874880    up_sampling2d_1[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_2 (UpSampling2D)  (None, 120, 160, 512 0           Frank[0][0]
# __________________________________________________________________________________________________
# Bob (Conv2D)                    (None, 120, 160, 128 4194432     up_sampling2d_2[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_3 (UpSampling2D)  (None, 240, 320, 128 0           Bob[0][0]
# __________________________________________________________________________________________________
# Joe (Conv2D)                    (None, 240, 320, 3)  387         up_sampling2d_3[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_4 (UpSampling2D)  (None, 480, 640, 3)  0           Joe[0][0]
# ==================================================================================================
# Total params: 70,245,123
# Trainable params: 23,069,699
# Non-trainable params: 47,175,424
# __________________________________________________________________________________________________
